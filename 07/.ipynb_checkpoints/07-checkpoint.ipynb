# %% [markdown]
# # <span style="color:red"> **LSN - Esercitazione 07**
# ### <span style="color:green"> 24.04.2025
# #### <span style="color:green"> Lucrezia Bioni (13655A)

# %% [markdown]
# ## <span style="color:blue">**Esercizio 07.1**

# %% [markdown]
# Nella quarta esercitazione, si è fatta un'approssimazione fuori controllo: nel calcolo dell'energia potenziale, si è trascurato il valore dell'integrale tra $R_{cut}$ e $\infty$.Per un generico potenziale, l'equazione che descrive tali correzioni è:
# $$
# <V>_{tail} \, =  \, 2 \pi \rho N \int_{r_{cut}} ^{+ \infty} dr r^2 v(r) g(r) \, \approx \, 2 \pi \rho N \int_{r_{cut}} ^{+ \infty} dr r^2 v(r)
# $$
# Per valori di $R_{cut}$ sufficientemente grandi, le oscillazioni di $g(r)$ sono sempre più smorzate, ed è dunque lecito approssimare $g(r) \approx 1$. \
# Nel caso di potenziale di Lennard-Jones, si ottiene:
# $$
# \frac{<V_{LJ}>_{tail}}{N} \, \approx  \, \frac{8 \pi \rho_{LJ} \epsilon}{9 r_{cut (LJ)}^9} - \frac{8 \pi \rho_{LJ} \epsilon}{3 r_{cut (LJ)}^3}
# $$
# La medesima approssimazione è stata fatta per la pressione. L'equazione che descrive le correzioni di coda in tal caso è:
# $$ \frac{<w_{LJ}>_{tail}}{3N \epsilon}  \, \approx  \, 32 \pi \rho_{LJ}  \left[ \frac{1}{9 r^9_{c(LJ)}} - \frac{1}{6 r^3_{c(LJ)}} \right] $$
# Pertanto, si sono aggiunte tali correzioni per il calcolo dell'energia potenziale e della pressione.

# %% [markdown]
# ## <span style="color:blue">**Esercizio 07.2**

# %% [markdown]
# Lo scopo di tale esercizio è individuare le migliori condizioni in cui effettuare una simulazione Monte Carlo ($N,V,T$: a temperatura costante) e una simulazione di Dinamica Molecolare ($N,V,E$, a energia costante). In particolare, si vogliono individuare il numero di timestep o passi Monte Carlo e la lunghezza dei blocchi in cui suddividere la simulazione migliori.

# %% [markdown]
# Si sono effettuate una simulazione MD e una simulazione MC. In entrambi i casi, si è scelto di lavorare in condizioni termodinamiche di fase liquida, che è la più complessa da descrivere a livello teorico poiché non si ha un modello di riferimento ideale (un analogo del gas ideale per i gas e del solido armonico per i solidi).
#
# Prima di effettuare la simulazione di interesse, si è fatta una simulazione di equilibrazione del sistema, con $5.000$ blocchi da $1$ step, partendo da una configurazione di cristallo perfetto $fcc$. Quindi, si è partiti dalla configurazione finale ottenuta e, tramite restart, si è effettuata la simulazione.

# %% [markdown]
# Si sono utilizzati i seguenti parametri:
# | Parametro         | <span style="color:red"> Valore (MD) | <span style="color:blue"> Valore (MC) |
# |-------------------|-------------|------------|
# | $N_{part}$        |            108            |
# | $\rho$            | 0.8                       |
# | $T^*$              | 1.1                       |
# | $ r_{cut}$        |   2.5                     |
# | $\delta$           | 0.001       | 0.1         |
# | $N_{blocks}$        | 500.000                   |
# |$ N_{steps}$         | 1                         |

# %% [markdown]
# Durante una simulazione di Dinamica Molecolare, finché non si raggiunge l'equilibrio, la temperatura non rimane costante; pertanto, per poter effettuare la simulazione equilibrata a temperatura $T^*=1.1$, è necessario effettuare l'equilibrazione partendo da una temperatura maggiore. Dopo qualche tentativo, si è osservato che si raggiunge la temperatura prefissata partendo da $T=2.0$. Il fatto che le due simulazioni siano effettuate alla medesima temperatura è necessario per poter fare un confronto tra di esse.
#
# Per la simulazione Monte Carlo, si è individuato il valore di $\delta = 0.1$ (ampiezza dello step in ogni direzione) che consentisse di avere accettanza al $50 \%$.

# %% [markdown]
# Dopo aver ottenuto l’intera serie temporale di $U/N$ da entrambe le simulazioni, si è calcolata la funzione di autocorrelazione, per studiare la correlazione i campioni nel tempo. Questo è stato fondamentale per determinare il tempo di correlazione tipico del sistema e, di conseguenza, per capire quanto ampi debbano essere i blocchi da utilizzare nella tecnica del data blocking.
#
# Successivamente, si è applicato il data blocking per calcolare l’incertezza statistica sulla media di $U/N$ in funzione della dimensione dei blocchi $L$, che è stata fatta variare da $10$ fino a $5000$. Tracciando l’andamento dell’incertezza al variare di $L$, si è identificata la dimensione ottimale dei blocchi: quando l’errore smette di crescere in modo significativo, infatti, aumentare ulteriormente $L$ non porta alcun vantaggio pratico, ma solo un inutile aumento del costo computazionale.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

t_max = 500_000

# Carico i dati dal file
data_MC = np.loadtxt("simulazioni-eseguite/07.2/monte-carlo-equilibrata/potential_energy.dat")
data_MD = np.loadtxt("simulazioni-eseguite/07.2/dinamica-molecolare-equilibrata/potential_energy.dat")

# importo in un array il numero di step che faccio e in un array il valore dell'energia potenziale a ogni valore di step

t = data_MC[:, 0]   # Prima colonna: contiene il numero di blocchi
U_MC = data_MC[:, 1]   # Seconda colonna: contiene il valore istantaneo di energia potenziale
U_MD = data_MD[:, 1]
autocorrelation_MC = [] # Array per contenere il valore della autocorrelazione
autocorrelation_MD = []
t_calcolati = []

for i in range(0,1000):
    a_MC = 0.0
    a_MD = 0.0
    b_MC = 0.0
    b_MD = 0.0
    c_MC = 0.0
    c_MD = 0.0
    d_MC = 0.0
    d_MD = 0.0
    e_MC = 0.0
    e_MD = 0.0
    for j in range( t_max - i ):
        a_MC += U_MC[j] * U_MC[j+i]
        a_MD += U_MD[j] * U_MD[j+i]
        b_MC += U_MC[j]
        b_MD += U_MD[j]
        c_MC += U_MC[j+i]
        c_MD += U_MD[j+i]
    for k in range ( t_max):
        d_MC += U_MC[k] * U_MC[k]
        d_MD += U_MD[k] * U_MD[k]
        e_MC += U_MC[k]
        e_MD += U_MD[k]
    autocorrelation_MC.append(( (1. / (t_max - i) * a_MC ) - 1./(t_max - i) * b_MC * 1./(t_max - i) * c_MC ) / ( (1./ t_max) * d_MC - ( (1./ t_max) * e_MC )**2 ))
    autocorrelation_MD.append(( (1. / (t_max - i) * a_MD ) - 1./(t_max - i) * b_MD * 1./(t_max - i) * c_MD ) / ( (1./ t_max) * d_MD - ( (1./ t_max) * e_MD )**2 ))
    t_calcolati.append(i)


fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 riga, 2 colonne

# Primo grafico
axes[0].plot(t_calcolati, autocorrelation_MC,  color='b', label='Monte Carlo')
axes[0].set_title("Funzioni di autocorrelazione di U/N")
axes[0].legend()
axes[0].grid(True)

# Secondo grafico
axes[1].plot(t_calcolati, autocorrelation_MD,  color='r', label='Dinamica Molecolare')
axes[1].set_title("Funzioni di autocorrelazione di U/N")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Si osserva che nel caso di simulazione Monte Carlo le funzioni di autocorrelazione sono compatibili con zero dopo circa $300$ passi, mentre nel caso di Dinamica Molecolare dopo circa $200$. Pertanto, è importante scegliere blocchi grandi almeno una decina di volte il tempo di autocorrelazione, con $L>10^3$

# %%
import numpy as np
import matplotlib.pyplot as plt

def block_average(data, n_blocks):
    N = len(data)
    if N % n_blocks != 0:
        data = data[:N - (N % n_blocks)]  # Trim so divisible by n_blocks
    block_size = len(data) // n_blocks
    blocks = data.reshape((n_blocks, block_size))
    means = blocks.mean(axis=1)
    mean_of_means = means.mean()
    std_error = np.sqrt(np.var(means, ddof=1) / n_blocks)
    return mean_of_means, std_error

T, enMD, _, errMD = np.loadtxt("simulazioni-eseguite/07.2/dinamica-molecolare-equilibrata/potential_energy.dat", usecols=(0, 1, 2, 3), unpack=True)
enMC, errMC = np.loadtxt("simulazioni-eseguite/07.2/monte-carlo-equilibrata/potential_energy.dat", usecols=(1, 3), unpack=True)

# Definisco la dimensione dei blocchi L
min_L = 10
max_L = 5000
step_L = 10
block_sizes = np.arange(min_L, max_L + 1, step_L)

errors_md = []
errors_mc = []
valid_block_sizes_md = []
valid_block_sizes_mc = []

M_md = len(enMD)
M_mc = len(enMC)

# MD
for L in block_sizes:
    if M_md // L < 2:
        continue  # Ho bisogno di almeno due blocchi per calcolare la varianza
    n_blocks = M_md // L
    _, err = block_average(enMD, n_blocks)
    errors_md.append(err)
    valid_block_sizes_md.append(L)

# MC
for L in block_sizes:
    if M_mc // L < 2:
        continue
    n_blocks = M_mc // L
    _, err = block_average(enMC, n_blocks)
    errors_mc.append(err)
    valid_block_sizes_mc.append(L)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(valid_block_sizes_md, errors_md, label='Dinamica molecolare', color='red', markersize=3)
plt.plot(valid_block_sizes_mc, errors_mc, label='Monte Carlo', color='blue', markersize=3)
plt.xlabel("Dimensione del blocco $L$")
plt.ylabel("Incertezza statistica")
plt.title("Stima dell'errore statistico di $U/N$ con data blocking al variare di L")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Per piccoli valori di $L$, le incertezze sono piccole, e poi crescono all'aumentare di $L$, fino a stabilizzarsi. Per $L>10^3$, il valore delle incertezze statistiche rimane costante. Per stimare bene l'incertezza statistica, dunque, è necessario effettuare data blocking con blocchi costituiti da almeno $2000$ step.

# %% [markdown]
# Il grafico sottostante riporta l'andamento di $U/N$, che rimane stabile durante il processo.

# %%
import matplotlib.pyplot as plt
import numpy as np

N = 108  # Numero totale di particelle

# Carico i dati dal file
data_U_MC = np.loadtxt("simulazioni-eseguite/07.2/monte-carlo-equilibrata/potential_energy.dat")
data_U_MD = np.loadtxt("simulazioni-eseguite/07.2/dinamica-molecolare-equilibrata/potential_energy.dat")

# Estraggo le colonne di dati
x = data_U_MC[:, 0]         # Prima colonna: numero di blocchi
y_U_MC = data_U_MC[:, 1]    # Seconda colonna: valori istantanei
err_U_MC = data_U_MC[:, 3]  # Quarta colonna: errore

y_U_MD = data_U_MD[:, 1]
err_U_MD = data_U_MD[:, 3]

# Creazione di una figura con 1 riga e 2 colonne
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# U/N Monte Carlo (primo grafico)
axes[0].errorbar(x, y_U_MC, yerr=err_U_MC, color='b', label='Monte Carlo')
axes[0].set_xlabel("Numero di blocchi")
axes[0].set_ylabel("U/N")
axes[0].set_title("Energia potenziale per particella (MC)")
axes[0].legend()
axes[0].grid(True)

# U/N Dinamica Molecolare (secondo grafico)
axes[1].errorbar(x, y_U_MD, yerr=err_U_MD, color='r', label='Dinamica Molecolare')
axes[1].set_xlabel("Numero di blocchi")
axes[1].set_ylabel("U/N")
axes[1].set_title("Energia potenziale per particella (MD)")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <span style="color:blue">**Esercizio 07.3**

# %% [markdown]
# Nel file `system.cpp`, si è implementata la funzione di distribuzione radiale $g(r)$, che è una quantità fondamentale per caratterizzare la struttura microscopica di un sistema di particelle. Essa descrive la probabilità normalizzata di trovare una coppia di particelle a distanza $r$, rispetto al valore atteso per un gas ideale alla stessa densità $\rho$. Matematicamente, $g(r)$ è definita come:
#
# $$g(r) = \frac{1}{\rho N \Delta V(r)} \langle \sum \sum_{i \neq j=1}^{N} \delta(|\vec{r}| - |\vec{r}_i - \vec{r}_j|) \rangle $$
# dove $\Delta V(r)$ = $\frac{4\pi}{3} \left[(r + dr)^3 - r^3\right]$ rappresenta il volume dell'intervallo sferico tra  $r$ e $r + dr$.
#
# Durante la simulazione, per ogni coppia di particelle $(i,j)$ si calcola la distanza $|\vec{r}_i - \vec{r}_j|$. Se questa distanza cade nell'intervallo $[r, r+dr)$, si incrementa di 2 (per simmetria) il corrispondente bin di un istogramma. Al termine della simulazione, l'istogramma viene normalizzato dividendo per $\rho N \Delta V(r)$, ottenendo così $g(r)$.

# %% [markdown]
# ## <span style="color:blue">**Esercizio 07.4**

# %% [markdown]
# Si sono effettuate una simulazione Monte Carlo e una simulazione di Dinamica Molecolare per un modello Lennard-Jones dell'Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu), con i seguenti parametri:

# %% [markdown]
# | Parametro         | <span style="color:red"> Valore (MD) | <span style="color:blue"> Valore (MC) |
# |-------------------|-------------|-------------|
# | $N_{part}$        |            108            |
# | $\rho$            | 0.8                       |
# | $T^*$              | 1.1                       |
# | $ r_{cut}$        |   2.5                     |
# | $\delta$           | 0.001       | 0.1         |
# | $N_{blocks}$        | 30                  |
# |$ N_{steps}$         | 5000                    |
#
# Anche in questo caso, si è fatta una prima simulazione di equilibrazione, e si sono pertanto scartati i prima $5.000$ passi. \
# Poiché il codice è scritto in modo che la temperatura venga dedotta dall'energia cinetica, lo si è modificato, nel caso di simulazione MC (a temperatura costante) in modo che, per il calcolo della pressione, prenda la temperatura in input.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

N = 108 # numero di particelle

# Carico i dati dal file
data_U_MC = np.loadtxt("simulazioni-eseguite/07.4/monte-carlo-equilibrata/OUTPUT/potential_energy.dat") # energia potenziale
data_U_MD = np.loadtxt("simulazioni-eseguite/07.4/dinamica-molecolare-equilibrata/OUTPUT/potential_energy.dat")
data_p_MC = np.loadtxt("simulazioni-eseguite/07.4/monte-carlo-equilibrata/OUTPUT/pressure.dat") 
data_p_MD = np.loadtxt("simulazioni-eseguite/07.4/dinamica-molecolare-equilibrata/OUTPUT/pressure.dat")

N_blocchi = data_U_MC[:, 0]   # Prima colonna: contiene il numero di blocchi

U_MC = data_U_MC[:,2] # Terza colonna: contiene il valore medio di energia potenziale
U_MD = data_U_MD[:,2] # Terza colonna: contiene il valore medio di energia potenziale
error_U_MC = data_U_MC[:,3] # Quarta colonna: contiene l'errore
error_U_MD = data_U_MD[:,3] # Quarta colonna: contiene l'errore

p_MC = data_p_MC[:,2] # Terza colonna: contiene il valore medio di pressione
p_MD = data_p_MD[:,2] # Terza colonna: contiene il valore medio di pressione
error_p_MC = data_p_MC[:,3] # Quarta colonna: contiene l'errore
error_p_MD = data_p_MD[:,3] # Quarta colonna: contiene l'errore



fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 riga, 2 colonne

# Primo grafico
axes[0].errorbar(N_blocchi, U_MC, yerr=error_U_MC , color='b', label='Monte Carlo')
axes[0].errorbar(N_blocchi, U_MD, yerr=error_U_MD , color='r', label='Dinamica Molecolare')
axes[0].set_title("Energia interna per particella")
axes[0].set_xlabel("Numero di blocchi")
axes[0].set_ylabel("U/N")
axes[0].legend()
axes[0].grid(True)

axes[1].errorbar(N_blocchi, p_MC, yerr=error_p_MC, color='b', label='Monte Carlo')
axes[1].errorbar(N_blocchi, p_MD, yerr=error_p_MD, color='r', label='Dinamica Molecolare')
axes[1].set_title("Pressione")
axes[1].set_xlabel("Numero di blocchi")
axes[1].set_ylabel("p")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parametri
n_bins = 100       # Numero di bin per blocco
target_block = 30  # Blocco da visualizzare (1-based)

# Funzione per caricare e estrarre i dati del blocco specificato
def load_block_data(filepath, block, n_bins):
    data = np.loadtxt(filepath)
    start_idx = (block - 1) * n_bins
    end_idx = block * n_bins
    return data[start_idx:end_idx, 0], data[start_idx:end_idx, 1], data[start_idx:end_idx, 2]

# Caricamento dati
r_mc, g_mc, err_mc = load_block_data("simulazioni-eseguite/07.4/monte-carlo-equilibrata/OUTPUT/gofr.dat", target_block, n_bins)
r_md, g_md, err_md = load_block_data("simulazioni-eseguite/07.4/dinamica-molecolare-equilibrata/OUTPUT/gofr.dat", target_block, n_bins)

# Creazione figura con due subplot affiancati
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot Monte Carlo
ax1.bar(r_mc, g_mc, 
        color='blue', 
        alpha=0.7, 
        width=(r_mc[-1] - r_mc[0])/n_bins,
        edgecolor='black',
        linewidth=0.5)
ax1.errorbar(r_mc, g_mc, yerr=err_mc,
             fmt='none', 
             ecolor='red',
             capsize=3,
             label='Errore')
ax1.set_title(f'Monte Carlo', fontsize=14)
ax1.set_xlabel('Distanza $r$', fontsize=12)
ax1.set_ylabel('$g(r)$', fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend()

# Plot Dinamica Molecolare
ax2.bar(r_md, g_md, 
        color='red', 
        alpha=0.7, 
        width=(r_md[-1] - r_md[0])/n_bins,
        edgecolor='black',
        linewidth=0.5)
ax2.errorbar(r_md, g_md, yerr=err_md,
             fmt='none', 
             ecolor='darkorange',
             capsize=3,
             label='Errore')
ax2.set_title(f'Dinamica Molecolare', fontsize=14)
ax2.set_xlabel('Distanza $r$', fontsize=12)
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend()

# Titolo generale e layout
plt.suptitle(f'Confronto distribuzioni radiali $g(r)$', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Come si può osservare dalle figure precedenti, i due metodi producono valori medi molto simili sia per la pressione che per l'energia potenziale per particella. Tuttavia, i risultati non sono perfettamente compatibili entro l'incertezza statistica. Questa piccola discrepanza può essere attribuita al fatto che le simulazioni Monte Carlo e Dinamica Molecolare campionano lo stesso ensemble termodinamico solo nel limite termodinamico, ovvero quando il numero di particelle tende a infinito.
#
# In questo caso, poiché le simulazioni sono state condotte con un numero finito e relativamente piccolo di particelle ($108$), è normale aspettarsi lievi differenze tra i due approcci. Queste divergenze minori possono essere una conseguenza del fatto che la pressione è molto sensibile alla temperatura media.
#
# Per quanto riguarda le funzioni di distribuzione radiale $g(r)$ mostrate negli ultimi grafici, queste appaiono praticamente identiche, in ottimo accordo con il comportamento teorico atteso. La corrispondenza tra i risultati conferma che, nonostante le differenze nei valori medi di pressione ed energia, entrambi i metodi catturano correttamente la struttura microscopica del sistema. Questo suggerisce che le discrepanze osservate siano principalmente legate a fluttuazioni statistiche o a effetti finiti del campionamento, piuttosto che a errori sistematici nelle simulazioni.
