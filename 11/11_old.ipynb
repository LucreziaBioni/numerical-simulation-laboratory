# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make predictions, we will consider a NN that depends on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2892 - mse: 1.2892 - val_loss: 0.8150 - val_mse: 0.8150
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8058 - mse: 0.8058 - val_loss: 0.5208 - val_mse: 0.5208
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5039 - mse: 0.5039 - val_loss: 0.3512 - val_mse: 0.3512
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3962 - mse: 0.3962 - val_loss: 0.2489 - val_mse: 0.2489
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2710 - mse: 0.2710 - val_loss: 0.1830 - val_mse: 0.1830
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1916 - mse: 0.1916 - val_loss: 0.1378 - val_mse: 0.1378
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1441 - mse: 0.1441 - val_loss: 0.1065 - val_mse: 0.1065
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1111 - mse: 0.1111 - val_loss: 0.0835 - val_mse: 0.0835
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.0662 - val_mse: 0.0662
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0753 - mse: 0.0753 - val_loss: 0.0527 - val_mse: 0.0527
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0337 - mse: 0.0337 - val_loss: 0.0271 - val_mse: 0.0271
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0285 - mse: 0.0285 - val_loss: 0.0218 - val_mse: 0.0218
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7682e-04 - mse: 9.7682e-04 - val_loss: 8.2976e-04 - val_mse: 8.2976e-04
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4526e-04 - mse: 8.4526e-04 - val_loss: 6.6735e-04 - val_mse: 6.6735e-04

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.954175]], dtype=float32), array([0.99940133], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5005e-04 - mse: 6.5005e-04
#
# Test loss: 0.0006673504249192774
# Test accuracy: 0.0006673504249192774

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.5005e-04 - mse: 6.5005e-04
#
# Test loss: 0.0006673504249192774
# Test accuracy: 0.0006673504249192774

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70bd401ce8e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70bd401ce8e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.add(Dense(200, input_shape=(2,), activation='relu'))
model.add(Dense(100, input_shape=(2,), activation='relu'))
model.add(Dense(80, input_shape=(2,), activation='relu'))
model.add(Dense(50, input_shape=(2,), activation='relu'))
model.add(Dense(25, input_shape=(2,), activation='relu'))
model.add(Dense(15, input_shape=(2,), activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7509e-05 - mse: 2.7509e-05 - val_loss: 1.7425e-04 - val_mse: 1.7425e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5666e-05 - mse: 4.5666e-05 - val_loss: 1.6894e-04 - val_mse: 1.6894e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7411e-05 - mse: 3.7411e-05 - val_loss: 1.6639e-04 - val_mse: 1.6639e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4869e-05 - mse: 2.4869e-05 - val_loss: 1.6221e-04 - val_mse: 1.6221e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7179e-05 - mse: 2.7179e-05 - val_loss: 1.5806e-04 - val_mse: 1.5806e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8245e-05 - mse: 2.8245e-05 - val_loss: 1.5414e-04 - val_mse: 1.5414e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3311e-05 - mse: 3.3311e-05 - val_loss: 1.5069e-04 - val_mse: 1.5069e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5646e-05 - mse: 2.5646e-05 - val_loss: 1.4756e-04 - val_mse: 1.4756e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1779e-05 - mse: 3.1779e-05 - val_loss: 1.4445e-04 - val_mse: 1.4445e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9963e-05 - mse: 2.9963e-05 - val_loss: 1.4210e-04 - val_mse: 1.4210e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9427e-05 - mse: 2.9427e-05 - val_loss: 1.3964e-04 - val_mse: 1.3964e-04

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)
x_valid = np.random.uniform(-1, 1, 1000)
x_valid.sort()
y_target = 4 - 3 *  x_valid - 2 *  x_valid *  x_valid + 3 *  x_valid *  x_valid * x_valid  # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(4 - 3 * x_train - 2 * x_train * x_train + 3 * x_train * x_train *x_train  , sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(4 - 3 * x_valid - 2 * x_valid * x_valid + 3 * x_valid * x_valid* x_valid , sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(264, input_shape=(1,), activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100,  activation='relu'))
model.add(Dense(80, activation='relu'))
model.add(Dense(50,activation='relu'))
model.add(Dense(25,  activation='relu'))
model.add(Dense(15,  activation='relu'))
model.add(Dense(1,))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_26 (Dense)                │ (None, 264)            │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 200)            │        53,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 80)             │         8,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 50)             │         4,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 15)             │           390 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 87,439 (341.56 KB)
#  Trainable params: 87,439 (341.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3820 - mse: 1.3820 - val_loss: 0.0913 - val_mse: 0.0913
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0319 - mse: 0.0319 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0101 - val_mse: 0.0101

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[-0.10407171, -0.06562578, -0.12267811,  0.00297917,  0.17517814,
#           0.02724912,  0.09007315,  0.01642605,  0.09383943, -0.23572665,
#          -0.04678141,  0.16963808,  0.10419387, -0.09425062,  0.08777004,
#           0.05380358,  0.1264313 , -0.22504653,  0.13605249, -0.00767559,
#          -0.13510089,  0.04200792, -0.09147634, -0.09363817,  0.13314895,
#           0.02148678, -0.17455344,  0.04321895,  0.00585931,  0.05839689,
#          -0.03044815, -0.18360983,  0.13570468, -0.00037091, -0.08862083,
#           0.08353218, -0.19496022, -0.15642446,  0.18128496,  0.13468921,
#          -0.05015874, -0.14877354,  0.05255545,  0.07008862,  0.07305116,
#           0.06058752,  0.07082378, -0.12259044, -0.04407801,  0.15282078,
#           0.0544295 ,  0.0716121 ,  0.06569119,  0.08045109, -0.09767339,
#          -0.16623679,  0.04505827,  0.02572226, -0.01742942,  0.10262663,
#           0.12575534, -0.02416264, -0.03535707, -0.03763855,  0.10323178,
#           0.00060893, -0.0228391 ,  0.15223528,  0.03683977, -0.03625755,
#           0.15425527,  0.08070575,  0.03166615,  0.12284955,  0.05504592,
#          -0.09715168, -0.01693824, -0.14629078,  0.05237573, -0.09588774,
#           0.01265303, -0.01156533,  0.12633133,  0.1654345 ,  0.10510668,
#           0.06112755, -0.05006843,  0.16555344, -0.1098438 , -0.04156087,
#          -0.04219646, -0.08917049, -0.08254687, -0.03587525,  0.07976148,
#           0.0140964 ,  0.10197731,  0.07679077,  0.00066417,  0.1771395 ,
#          -0.00938632,  0.07785687, -0.03700074,  0.08672169, -0.11541696,
#           0.1859546 ,  0.05211272, -0.18843749,  0.12337729, -0.14549772,
#          -0.14520718,  0.13340767, -0.032391  ,  0.17186531,  0.07835015,
#          -0.03496475,  0.10795159, -0.05092425, -0.185363  , -0.00862155,
#           0.02865316, -0.06349733, -0.08423472, -0.04834877,  0.05489583,
#           0.0146415 , -0.16347665,  0.10097034, -0.17832346, -0.05134814,
#          -0.12630163, -0.06840384,  0.0681793 ,  0.15235768, -0.01833839,
#           0.0460665 ,  0.02578011,  0.07555756,  0.15943582, -0.05617664,
#          -0.21360537, -0.05015212,  0.0303489 ,  0.13465826,  0.03561956,
#          -0.03931787,  0.09783355,  0.13979632, -0.00113069, -0.02767677,
#           0.05390017,  0.04725071,  0.06302762,  0.12440927,  0.08270168,
#           0.0579007 , -0.08002366, -0.15580262, -0.1327133 ,  0.07275904,
#          -0.20572574,  0.08104359,  0.09146547,  0.04941895, -0.07649903,
#           0.04598977, -0.04759594, -0.08914992,  0.03073682, -0.20265837,
#           0.04915549, -0.04737233],
#         [-0.1683041 , -0.14287561, -0.14428787, ...,  0.15992658,
#          -0.14322054, -0.03868414]], dtype=float32),
#  array([ 0.        , -0.00770535,  0.02027979, -0.04451945,  0.03769049,
#          0.        ,  0.04699178,  0.0032813 ,  0.047354  ,  0.06415552,
#         -0.01547294, -0.06727962, -0.00883092, -0.00158445, -0.04326202,
#          0.01467684, -0.04580158,  0.05822336,  0.00520262,  0.02101887,
#         -0.02954828,  0.00492052, -0.01582723,  0.05334657,  0.03350059,
#          0.00423437, -0.00516511,  0.03017245,  0.02775074, -0.00146806,
#         -0.02609566,  0.00471427, -0.03175187,  0.00910598,  0.05351815,
#         -0.00287573, -0.03437744, -0.00857179,  0.08513867,  0.07080229,
#         -0.00716241,  0.05835938,  0.02016363,  0.0662681 , -0.00242939,
#          0.022018  , -0.00970517,  0.08641834,  0.00601413,  0.        ],
#        dtype=float32),
#  array([[-0.08876787, -0.06457606,  0.22241977, ..., -0.23754552,
#          -0.12708274, -0.23614657],
#         [ 0.21310547, -0.2631991 , -0.04456602, ...,  0.1406533 ,
#          -0.12151898, -0.08547267],
#         [-0.15535092,  0.1359532 ,  0.17282023, ..., -0.22736365,
#           0.25221732,  0.21662517],
#         ...,
#         [-0.01512325,  0.05524867,  0.08239373, ...,  0.1697374 ,
#           0.2561307 ,  0.23900901],
#         [ 0.25298992, -0.25405654, -0.04655788, ..., -0.12659076,
#           0.26469278,  0.14232749],
#         [ 0.25102696, -0.04476447, -0.09968297, ...,  0.2604927 ,
#          -0.00756115,  0.06410232]], dtype=float32),
#  array([ 0.        ,  0.04739111,  0.01743881,  0.02245243,  0.00791753,
#          0.01571102, -0.012366  ,  0.        ,  0.10872531,  0.10405147,
#          0.        , -0.01093771,  0.        ,  0.10653125,  0.        ,
#         -0.00034244,  0.        ,  0.10476341,  0.01064693, -0.01107032,
#         -0.0183148 ,  0.        ,  0.24586982, -0.03559781, -0.01320769],
#        dtype=float32),
#  array([[-0.38184914, -0.22815502, -0.2447814 , -0.22594312,  0.12943083,
#          -0.23311566,  0.37980908,  0.2844175 ,  0.33696103, -0.3410635 ,
#           0.2924798 , -0.24848679,  0.2510556 ,  0.21776271,  0.31024104],
#         [ 0.05566457, -0.03686107,  0.02399308,  0.19620046,  0.26640856,
#           0.26904613,  0.32427776,  0.29965323, -0.05754079,  0.13591152,
#           0.25239336,  0.1184243 ,  0.03929367,  0.20609069, -0.06805804],
#         [-0.26853925, -0.23771122,  0.09677003, -0.1355509 ,  0.04221155,
#           0.04065115,  0.30354744, -0.01450298,  0.05436828, -0.26351118,
#           0.25164568,  0.33621845, -0.1787509 ,  0.22804336,  0.1328253 ],
#         [ 0.12407491, -0.03188574, -0.01483281,  0.00544312,  0.00382302,
#          -0.06247265, -0.22930928,  0.0030316 ,  0.01330461,  0.00373596,
#          -0.33862692, -0.14800452, -0.02453154,  0.2655917 ,  0.21117501],
#           0.20568484, -0.09314671, -0.21187599,  0.22812527, -0.19874953,
#           0.38450527,  0.00579226,  0.02176046, -0.14564335, -0.21953072],
#         [ 0.28753868, -0.09539689, -0.03084055,  0.12604794, -0.33653527,
#          -0.09536064,  0.25153756, -0.22196917, -0.20498028, -0.24099803,
#           0.38238648, -0.22082525,  0.34047318,  0.13521312,  0.06760686],
#         [-0.049367  , -0.39644912, -0.34790283,  0.15894239, -0.042776  ,
#           0.309574  ,  0.31507516, -0.01354246, -0.14696926,  0.17598766,
#          -0.12340525,  0.3416292 , -0.25399917,  0.27376416, -0.02142633],
#         [ 0.2535696 ,  0.08982839,  0.13852002, -0.16621059,  0.08368025,
#           0.15316105, -0.09646848,  0.30113748,  0.3672307 ,  0.3485901 ,
#          -0.05478035, -0.04682833,  0.10268442,  0.34183002,  0.16587335],
#         [ 0.26684353,  0.12423188,  0.32675833, -0.20536761, -0.03891482,
#          -0.2507241 ,  0.06235574, -0.22808844,  0.2889999 , -0.22434519,
#           0.05444332,  0.19386984,  0.08167981, -0.16583736,  0.15194647],
#         [ 0.09999061,  0.36102003, -0.3060592 ,  0.19675803, -0.22316723,
#           0.07971951, -0.24869862,  0.21948665, -0.37992793, -0.21602876,
#          -0.28058478,  0.22115856, -0.3455086 , -0.30144733,  0.13341159],
#         [ 0.30824474,  0.27191266,  0.11328756, -0.2104147 ,  0.03123474,
#           0.3585641 ,  0.2190162 , -0.15714645,  0.11913207, -0.2072038 ,
#           0.06632505,  0.06354302,  0.43091616, -0.07944051, -0.00087597],
#         [-0.05290398,  0.09801801,  0.09485606,  0.2404309 , -0.16396534,
#          -0.18072236,  0.09441742,  0.13716416,  0.3075468 , -0.13992526,
#           0.2140616 , -0.28701898,  0.02724331,  0.2742642 ,  0.30142048],
#         [-0.26700962, -0.28107178,  0.2722495 , -0.12400783,  0.07843407,
#           0.29249746, -0.3247404 ,  0.15024723,  0.02550361,  0.05558983,
#          -0.05174015, -0.01058265,  0.02507867, -0.3314744 ,  0.18392953]],
#        dtype=float32),
#  array([ 1.11459672e-01,  2.38445655e-01, -5.12691215e-03, -1.72914699e-01,
#         -1.52688287e-02,  2.53258552e-02,  2.80257046e-01, -4.21959534e-02,
#          3.80577962e-03, -1.06535899e-02,  2.04730183e-01,  1.32322535e-02,
#          2.30737120e-01, -2.45738367e-04, -9.66008753e-02], dtype=float32),
#  array([[ 0.3647845 ],
#         [ 0.6010357 ],
#         [-0.12489294],
#         [-0.44618705],
#         [ 0.05430789],
#         [-0.5982323 ],
#         [ 0.84666425],
#         [-0.5553101 ],
#         [-0.5271346 ],
#         [-0.11314886],
#         [ 0.6267437 ],
#         [-0.2422812 ],
#         [ 0.8147389 ],
#         [-0.11137156],
#         [-0.16742268]], dtype=float32),
#  array([0.4527287], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mse: 0.0099
#
# Test loss: 0.010104542598128319
# Test accuracy: 0.010104542598128319

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0064e-04 - mse: 1.0064e-04
#
# Test loss: 0.00018972523685079068
# Test accuracy: 0.00018972523685079068

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-2, 2, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# vedere cosa succede se do dati fuori range

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(low=-3./2, high=3./2, size=(1000, 2))
x_valid = np.random.uniform(low=-3./2, high=3./2, size=(100, 2))
#x_valid.sort
y_target = np.sin(x_train[:, 0]**2 + x_train[:, 1]**2)

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(np.sin(x_train[:, 0]**2 + x_train[:, 1]**2), scale=sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(np.sin(x_valid[:, 0]**2 + x_valid[:, 1]**2), scale=sigma)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Coordinate
x = x_valid[:, 0]
y = x_valid[:, 1]
z_target = y_target
z_valid = y_valid

# Plot 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z_target, color='blue', label='target', alpha=0.6, s=20)
ax.scatter(x, y, z_valid, color='red', label='validation data', alpha=0.6, s=20)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Target function vs Validation data')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from mpl_toolkits.mplot3d import Axes3D
#       4 # Coordinate
# ----> 5 x = x_valid[:, 0]
#       6 y = x_valid[:, 1]
#       7 z_target = y_target
#
# NameError: name 'x_valid' is not defined

# %%
grid_x, grid_y = np.meshgrid(np.linspace(-1.5, 1.5, 100), np.linspace(-1.5, 1.5, 100))
grid_z = np.sin(grid_x**2 + grid_y**2)

# Plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Superficie continua (funzione target)
ax.plot_surface(grid_x, grid_y, grid_z, cmap='viridis', alpha=0.7, edgecolor='none', label='Target function')

# Scatter dati di training
ax.scatter(x_train[:, 0], x_train[:, 1], y_train, color='blue', s=10, alpha=0.5, label='Training data')

# Scatter dati di validazione
ax.scatter(x_valid[:, 0], x_valid[:, 1], y_valid, color='red', s=10, alpha=0.6, label='Validation data')

# Etichette
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z = sin(x² + y²)')
ax.set_title('Target Function as Surface + Noisy Data')
plt.tight_layout()

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model1 = tf.keras.Sequential()
model1.add(Dense(264, input_shape=(1,), activation='relu'))
model1.add(Dense(200, activation='relu'))
model1.add(Dense(100,  activation='relu'))
model1.add(Dense(80, activation='relu'))
model1.add(Dense(50,activation='relu'))
model1.add(Dense(25,  activation='relu'))
model1.add(Dense(15,  activation='relu'))
model1.add(Dense(1,))

# compile the model choosing optimizer, loss and metrics objects
model1.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model1.summary()

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>
