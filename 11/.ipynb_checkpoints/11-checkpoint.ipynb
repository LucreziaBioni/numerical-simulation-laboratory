# %% [markdown]
# # <span style="color:red"> **LSN - Esercitazione 11**
# ### <span style="color:green"> 29.05.2025
# #### <span style="color:green"> Lucrezia Bioni (13655A)

# %% [markdown]
# ### <span style="color:blue">**_Keras - Regressione lineare con Neural Network_**

# %% [markdown]
# Lo scopo di questa esercitazione è affrontare un problema di regressione su dati rumorosi usando una Rete Neurale (NN). In particolare, si vuole mostrare come la capacità di approssimazione dipenda dalla struttura della NN (numero di layer, neuroni, funzioni di attivazione), perché la predizione risulta complessa in presenza di rumore e quali sono le strategie per migliorare l'accuratezza del modello. L'obiettivo è sviluppare un'intuizione pratica sui compromessi tra: sottodattamento (modello troppo semplice), sovradattamento (modello troppo complesso) e generalizzazione (prestazioni su dati mai visti).

# %% [markdown]
# **Il Problema della Predizione**
#
# Consideriamo un processo probabilistico che genera dati etichettati $(x,y)$. I dati sono prodotti estraendo campioni dall'equazione:
#
# $$
# y_i = f(x_i) + \eta_i
# $$
#
# dove $f(x_i)$ è una funzione fissa (potenzialmente sconosciuta), $\eta_i$ è un rumore gaussiano scorrelato con proprietà:
#   $$
#   \langle \eta_i \rangle = 0 \\
#   \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
#   $$
#
# Chiameremo $f(x_i)$ le **caratteristiche vere** del processo generatore.
#
# Per fare predizioni, utilizzeremo una NN con parametri (pesi e bias). Le funzioni che la NN può rappresentare costituiscono la **classe di modelli** disponibile per approssimare i dati.
#
# Per apprendere i parametri della rete, alleneremo i modelli su un set di dati di training
#
# ### Strategia di Apprendimento
#
# 1. **Divisione dei Dati**:
#    - **Training set**: per apprendere i parametri
#    - **Validation set**: per testare le predizioni su dati mai visti
#    *(Essenziale per valutare la capacità di generalizzazione)*
#
# 2. **Metrica di Performance**:
#    - Confronto tra predizioni $\{y_j^\mathrm{pred}\}$ e valori veri $\{y_j\}$
#    - **Errore Quadratico Medio (MSE)**:
#      $$
#      MSE = \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
#      $$
#
# ### Analisi Qualitativa
# - Visualizzeremo gli andamenti su:
#   - Dati di training (per monitorare l'apprendimento)
#   - Dati di validazione (per valutare overfitting)
# - Focus sull'interpretazione degli esiti piuttosto che su valori assoluti
#
# **Punti Chiave**:
# - Il rumore $\eta_i$ rende il problema intrinsecamente probabilistico
# - La separazione train/validation è cruciale per stimare la capacità predittiva reale
# - Il MSE quantifica gli errori ma l'ispezione visiva resta essenziale
#
# Ne
