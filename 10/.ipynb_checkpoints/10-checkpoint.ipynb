# %% [markdown]
# # <span style="color:red"> **LSN - Esercitazione 10**
# ### <span style="color:green"> 22.05.2025
# #### <span style="color:green"> Lucrezia Bioni (13655A)

# %% [markdown]
# - devo aggiungere rank a costruttori della classe Population, per distinguere ciascuna popolazione (una per continente)
# - ho aggiunto al metodo "evolve" la possibilità che _n_migranti individui migrino ogni _N_migr generazioni.
# - stampo "results" per ogni rank, ma poi plotterò solo quelli del rank 0 (che è quello che prende info da tutti gli altri)

# %% [markdown]
# 2000 generazioni, 1000 individui \
# n_migranti = 10, N_migr = 10 -> 66.0332 \
# n_migranti = 30, N_migr = 50 ->  65.8904 \
# n_migranti = 50, N_migr = 50 ->   69.4244 \
#
# 5000 generazioni, 1000 individui \
# n_migranti = 30, N_migr = 50 ->  65.8904 \
#
# 3000 generazioni, 2000 individui \
# n_migranti = 30, N_migr = 50 ->  69.2559 \
#
# 3000 generazioni, 1000 individui \
# n_migranti = 30, N_migr = 100 ->  69.2733 \
#
# 3000 generazioni, 1000 individui \
# n_migranti = 30, N_migr = 50 ->  65.8904 \
#
# 3000 generazioni, 2000 individui \
# n_migranti = 30, N_migr = 50 ->  69.2559 \
# n_migranti = 50, N_migr = 50 ->  69.4255  \
# n_migranti = 10, N_migr = 50 ->   69.5102 \
#
# 3000 generazioni, 500 individui \
# n_migranti = 30, N_migr = 50 -> 70.6079 \
#
# 20000 generazioni, 100 individui \
# n_migranti = 30, N_migr = 500 -> 68.0056 \
#
# 3000 generazioni, 2000 individui \
# n_migranti = 30, N_migr = 50 -> 69.2559 \

# %%
import matplotlib.pyplot as plt

def leggi_percorso(file):
    with open(file) as f:
        return [int(line.strip()) for line in f if line.strip() and not line.startswith('#')]

def leggi_coordinate(file):
    with open(file) as f:
        return [tuple(map(float, line.split())) for line in f if line.strip() and not line.startswith('#')]

def disegna_percorso(percorso_file, coordinate_file):
    # Leggi i dati
    percorso = leggi_percorso(percorso_file)
    coordinate = leggi_coordinate(coordinate_file)
    
    # Prepara i punti del percorso
    x = [coordinate[i-1][0] for i in percorso]
    y = [coordinate[i-1][1] for i in percorso]
    x.append(x[0])  # Chiudi il cerchio
    y.append(y[0])
    
    # Crea il grafico
    plt.figure(figsize=(10, 10))
    plt.plot(x, y, 'b-', linewidth=1, label='Percorso')
    plt.plot(x[:-1], y[:-1], 'ro', markersize=4, label='Città')
    
    # Aggiungi numeri
    for i, (xi, yi) in enumerate(zip(x[:-1], y[:-1])):
        plt.text(xi, yi, str(percorso[i]), fontsize=8)
    
    plt.title('Percorso ottimale tra 110 città')
    plt.xlabel('Longitudine')
    plt.ylabel('Latitudine')
    plt.grid(True, alpha=0.3)
    plt.legend()
    
    # Salva e mostra
    plt.savefig('percorso.png', dpi=150)
    plt.show()

if __name__ == "__main__":
    disegna_percorso("global_best_route.dat", "cap_prov_ita.dat")
