# %% [markdown]
# # <span style="color:red"> **LSN - Esercitazione 02**
# ### <span style="color:green"> 13.03.2025
# #### <span style="color:green"> Lucrezia Bioni (13655A)

# %% [markdown]
# Note:
# #### Esercizio 02.1:
# - provare a fare importance sampling con una p(x) con una funzione molto diversa dall'integranda
#
# #### Esercizio 02.2:
# - fare punto 1
# - fare punto 2

# %% [markdown]
# ## <span style="color:blue">**Esercizio 02.1**

# %% [markdown]
# Calcolo l'integrale 1D tramite metodo Monte Carlo
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$

# %% [markdown]
# 1. Stima tramite metodo della media, campionando uniformemente l'intervallo [0,1):

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

# Carico i dati dal file
data = np.loadtxt("02.1/data_media.dat")

# Estraggo le colonne di dati
x = data[:, 0]   # Prima colonna: contiene il numero di lanci nei blocchi considerati
y = data[:, 2]   # Terza colonna: differenza tra il valore medio di integrale ottenuto e il valore atteso
err = data[:, 3] # Quarta colonna: errore (deviazione standard)

# Creo il grafico con barre d'errore
plt.errorbar(x, y, yerr=err,label="Dati e incertezze",color='b')
plt.xlabel("Numero di blocchi")
plt.ylabel("I - 1")
plt.title("Stima di I con metodo della media")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Va bene che non sia dentro 1 $\sigma$ il risultato. Rientra entro $2 \sigma$.

# %% [markdown]
# 2. Stima tramite importance sampling

# %% [markdown]
# Fattorizzo l'integranda in funzione su cui valutare i punti campionati e distribuzione di probabilità. Ottengo una buona stima della distribuzione di probabilità effettuando lo sviluppo di taylor dell'integranda attorno a x = 1. Questo dovrebbe darmi un buon risultato.

# %%
# Carico i dati dal file
data = np.loadtxt("02.1/data_importance.dat")

# Estraggo le colonne di dati
x = data[:, 0]   # Prima colonna: contiene il numero di lanci nei blocchi considerati
y = data[:, 2]   # Terza colonna: differenza tra il valore medio di integrale ottenuto e il valore atteso
err = data[:, 3] # Quarta colonna: errore (deviazione standard)

# Creo il grafico con barre d'errore
plt.errorbar(x, y, yerr=err,label="Dati e incertezze",color='b')
plt.xlabel("Numero di blocchi")
plt.ylabel("I - 1")
plt.title("Stima di I con metodo Importance sampling")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# è molto più preciso del metodo precedente, come atteso.

# %% [markdown]
# ## <span style="color:blue">**Esercizio 02.2**

# %% [markdown]
# 1. Simulo random walk tradizionale su un reticolo cubico con lattice constant a = 1.
